# %% [markdown]
# # Cost Function

# %% [markdown]
# ## Definition
# If we have a line as y = ax + b, y = wx +b a as referenced in the course, the cost function could be outlined as the following
#
# $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2\tag{2}$$

# %%
import app.regression as ar
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.axhline(0, color='b')
plt.axvline(0, color='b')

l = ar.Feature(-2, 1)
xs = range(-10, 10)
ys = [ar.actual_y(x, l) for x in xs]

ax.plot(xs, ys, label='y')

ax.set_title('Function (1*x + 1)')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.legend()

train_data = [ar.Point(-9, -10.3), ar.Point(-7.5, -5), ar.Point(-5, -4.75), ar.Point(3, 2), 
              ar.Point(4, 5), ar.Point(5, 7), ar.Point(6, 8.3), ar.Point(7.5, 8.1)]

for train_datum in train_data:
    plt.plot(train_datum.x, train_datum.y, "s")

cost = ar.cost(train_data, l)
print(f"cost 1 is : {cost}")


fig2, ax2 = plt.subplots()
plt.axhline(0, color='b')
plt.axvline(0, color='b')

cxs = list(range(-10, 13))
cys = [ar.cost(train_data, ar.Feature(x, 0)) for x in cxs]
ax2.plot(cxs, cys, label='cost')
ax2.set_title('Cost Function')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.legend()

def cost(points: list[ar.Point], feature: ar.Feature):
    res = 0.0
    for pt in points:
        act = ar.actual_y(pt.x, feature)
        res += pow(act - pt.y, 2)
    m = len(points)
    res = res / (2 * m)
    return res

for cx in cxs:
    cst = cost(train_data, ar.Feature(cx, 0))
    print(f"x {cx}, y: {cst}")
# Out:
# cost 1 is : 178.59078125000002
# x -10, y: 2332.88453125
# x -9, y: 1930.6032812499998
# x -8, y: 1566.38453125
# x -7, y: 1240.22828125
# x -6, y: 952.13453125
# x -5, y: 702.10328125
# x -4, y: 490.13453125
# x -3, y: 316.22828125
# x -2, y: 180.38453125
# x -1, y: 82.60328125
# x 0, y: 22.884531250000002
# x 1, y: 1.2282812500000002
# x 2, y: 17.63453125
# x 3, y: 72.10328125000001
# x 4, y: 164.63453125
# x 5, y: 295.22828125
# x 6, y: 463.88453125
# x 7, y: 670.6032812500001
# x 8, y: 915.38453125
# x 9, y: 1198.22828125
# x 10, y: 1519.13453125
# x 11, y: 1878.1032812500002
# x 12, y: 2275.1345312500002

# %% [markdown]
# ## Cost Function Using Numpy
#
# In order to use numpy we should see how many features do we have
# So for y = ax + b we need the following structure
# - y : ndarray
# - a : ndarray
# - b : scalar

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.array([-9, -7.5, -5, 3, 4, 5, 6, 7.5])
ys = np.array([-10.3, -5, -4.75, 2, 5, 7, 8.3, 8.1])

_, ax = plt.subplots()
plt.axhline(0, color='b')
plt.axvline(0, color='b')

ax.set_title('Function (1*x + 1)')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.legend()

plt.plot(xs, ys, "s")

#a = -2, b = 1
m = len(xs)
guess = xs * -2 -1
errys_sq = (guess - ys) ** 2
print(f"xs    : {xs}")    
print(f"ys    : {ys}")
print("formulae is y=-1x-1")
print(f"guess : {guess}")    
print(f"rest :  {errys_sq}") 
print(sum(errys_sq) / 2 * m)

cxs = list(range(-10, 13))

for cx in cxs:
    m = len(xs)
    guess = xs * cx + 0
    errys_sq = (guess - ys) ** 2
    cst =sum(errys_sq) / (2 * m)
    print(f"x {cx}, y: {cst}")
# Out:
# xs    : [-9.  -7.5 -5.   3.   4.   5.   6.   7.5]
# ys    : [-10.3   -5.    -4.75   2.     5.     7.     8.3    8.1 ]
# formulae is y=-1x-1
# guess : [ 17.  14.   9.  -7.  -9. -11. -13. -16.]
# rest :  [745.29   361.     189.0625  81.     196.     324.     453.69   580.81  ]
# 11723.41
# x -10, y: 2332.88453125
# x -9, y: 1930.6032812499998
# x -8, y: 1566.38453125
# x -7, y: 1240.22828125
# x -6, y: 952.13453125
# x -5, y: 702.10328125
# x -4, y: 490.13453125
# x -3, y: 316.22828125
# x -2, y: 180.38453125
# x -1, y: 82.60328125
# x 0, y: 22.884531250000002
# x 1, y: 1.2282812500000002
# x 2, y: 17.63453125
# x 3, y: 72.10328125000001
# x 4, y: 164.63453125
# x 5, y: 295.22828125
# x 6, y: 463.88453125
# x 7, y: 670.6032812500001
# x 8, y: 915.38453125
# x 9, y: 1198.22828125
# x 10, y: 1519.13453125
# x 11, y: 1878.1032812500002
# x 12, y: 2275.1345312500002
# C:\Users\G55278\AppData\Local\Temp\ipykernel_16788\210832010.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
